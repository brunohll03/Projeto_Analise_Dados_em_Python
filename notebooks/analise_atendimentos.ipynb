# %% [markdown]
# # Análise de Atendimentos
#
# Este notebook será utilizado para exploração, análise e visualização
# dos dados de atendimentos médicos do projeto.
#
# As análises realizadas neste notebook têm finalidade educacional.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/atendimentos.csv")

# %%
df
# Out:
#     id              nome  idade      cidade  especialidade     status  \
# 0    1        Bruno Lima   30.0     Vinhedo  Clinico Geral  Concluido
# 1    2         Ana Souza    NaN    Campinas    Cardiologia   Agendado
# 2    3     Carlos Mendes   40.0     Jundiai      Ortopedia  Cancelado
# 3    4    Mariana Silva    35.0   Valinhos       Pediatria  Concluido
# 4    5       Joao Santos   52.0    Campinas    Cardiologia  Concluido
# 5    5       Joao Santos   52.0    Campinas    Cardiologia  Concluido
# 6    6    Pedro Oliveira   28.0    Campinas    Cardiologia  concluido
# 7    7     Juliana Costa   45.0    CAMPINAS    cardiologia   AGENDADO
# 8    8    Marcos Pereira   67.0   Campinas       ORTOPEDIA  Cancelado
# 9    9    Fernanda Alves   29.0     Vinhedo   Dermatologia  Concluido
# 10  10      Rafael Souza    NaN     Jundiai    Cardiologia   agendado
# 11  11     Patricia Lima   38.0    Campinas      Pediatria  CONCLUIDO
# ...

# %%
df.shape
# Out:
# (31, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             31 non-null     int64
#  1   nome           31 non-null     str
#  2   idade          28 non-null     float64
#  3   cidade         31 non-null     str
#  4   especialidade  31 non-null     str
#  5   status         31 non-null     str
#  6   email          31 non-null     str
#  7   telefone       31 non-null     int64
# dtypes: float64(1), int64(2), str(5)
# memory usage: 2.1 KB

# %%
df.describe()
# Out:
#               id       idade      telefone
# count  31.000000   28.000000  3.100000e+01
# mean   15.161290   41.357143  1.199999e+10
# std     8.858505   25.670583  8.193887e+00
# min     1.000000   -5.000000  1.199999e+10
# 25%     7.500000   29.750000  1.199999e+10
# 50%    15.000000   37.000000  1.199999e+10
# 75%    22.500000   46.000000  1.199999e+10
# max    30.000000  150.000000  1.199999e+10

# %%
df.isnull().sum()
# Out:
# id               0
# nome             0
# idade            3
# cidade           0
# especialidade    0
# status           0
# email            0
# telefone         0
# dtype: int64

# %%
df["status"].unique()
# Out:
# <StringArray>
# ['Concluido',  'Agendado', 'Cancelado', 'concluido',  'AGENDADO',  'agendado',
#  'CONCLUIDO']
# Length: 7, dtype: str

# %%
df["status"].value_counts()
# Out:
# status
# Concluido    13
# Agendado      6
# Cancelado     6
# concluido     2
# CONCLUIDO     2
# AGENDADO      1
# agendado      1
# Name: count, dtype: int64

# %%
df["especialidade"].value_counts()
# Out:
# especialidade
# Cardiologia      10
# Pediatria         6
# Dermatologia      5
# Ortopedia         4
# Clinico Geral     3
# cardiologia       1
# ORTOPEDIA         1
#  Pediatria        1
# Name: count, dtype: int64

# %%
df["cidade"].value_counts()
# Out:
# cidade
# Campinas      13
# Vinhedo        6
# Valinhos       5
# Jundiai        2
#  Valinhos      1
# CAMPINAS       1
#  Campinas      1
#  Campinas      1
# JUNDIAI        1
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 31

# %%
df["idade"].mean()
# Out:
# np.float64(41.357142857142854)

# %%
df["idade"].min()
# Out:
# np.float64(-5.0)

# %%
df["idade"].max()
# Out:
# np.float64(150.0)

# %%
df[df["idade"].isnull()]
# Out:
#     id              nome  idade    cidade especialidade    status  \
# 1    2         Ana Souza    NaN  Campinas   Cardiologia  Agendado
# 10  10      Rafael Souza    NaN   Jundiai   Cardiologia  agendado
# 25  25  Vanessa Oliveira    NaN  Valinhos     Pediatria  Agendado
#
#                          email     telefone
# 1          ana.souza@email.com  11999990002
# 10      rafael.souza@email.com  11999990010
# 25  vanessa.oliveira@email.com  11999990024

# %%
df["idade"].median()
# Out:
# np.float64(37.0)

# %%
df["idade"] = df["idade"].fillna(df["idade"].median())

# %%
df[df["idade"] > 100]
# Out:
#     id            nome  idade    cidade especialidade     status  \
# 12  12  Gabriel Santos  150.0  Valinhos     Ortopedia  Concluido
#
#                        email     telefone
# 12  gabriel.santos@email.com  11999990012

# %%
df[df["idade"] < 0]
# Out:
#     id          nome  idade   cidade  especialidade    status  \
# 19  19  Julio Santos   -5.0  Vinhedo  Clinico Geral  Agendado
#
#                      email     telefone
# 19  julio.santos@email.com  11999990019

# %%
df[(df["idade"] < 0) | (df["idade"] > 100)]
# Out:
#     id            nome  idade    cidade  especialidade     status  \
# 12  12  Gabriel Santos  150.0  Valinhos      Ortopedia  Concluido
# 19  19    Julio Santos   -5.0   Vinhedo  Clinico Geral   Agendado
#
#                        email     telefone
# 12  gabriel.santos@email.com  11999990012
# 19    julio.santos@email.com  11999990019

# %%
df.loc[(df["idade"] < 0) | (df["idade"] > 100), "idade"] = pd.NA

# %%
df["cidade"].unique()
# Out:
# <StringArray>
# [   'Vinhedo',   'Campinas',    'Jundiai', ' Valinhos ',   'CAMPINAS',
#  ' Campinas ',   'Valinhos',  ' Campinas',    'JUNDIAI']
# Length: 9, dtype: str

# %%
df["cidade"] = df["cidade"].str.strip()

# %%
df["cidade"] = df["cidade"].str.lower()

# %%
df["especialidade"] = df["especialidade"].str.strip()

# %%
df["especialidade"] = df["especialidade"].str.lower()

# %%
df["especialidade"].unique()
# Out:
# <StringArray>
# ['clinico geral', 'cardiologia', 'ortopedia', 'pediatria', 'dermatologia']
# Length: 5, dtype: str

# %%
df["status"] = df["status"].str.strip()

# %%
df["status"] = df["status"].str.lower()

# %%
df["status"].unique()
# Out:
# <StringArray>
# ['concluido', 'agendado', 'cancelado']
# Length: 3, dtype: str

# %%
df[df["email"].duplicated(keep=False)]
# Out:
#     id            nome  idade    cidade especialidade     status  \
# 4    5     Joao Santos   52.0  campinas   cardiologia  concluido
# 5    5     Joao Santos   52.0  campinas   cardiologia  concluido
# 14  14  Lucas Ferreira   41.0  campinas   cardiologia   agendado
# 29  29  Lucas Ferreira   41.0  campinas   cardiologia   agendado
#
#                        email     telefone
# 4      joao.santos@email.com  11999990005
# 5      joao.santos@email.com  11999990005
# 14  lucas.ferreira@email.com  11999990014
# 29  lucas.ferreira@email.com  11999990014

# %%
df[df["telefone"].duplicated(keep=False)]
# Out:
#     id             nome  idade    cidade especialidade     status  \
# 3    4   Mariana Silva    35.0  valinhos     pediatria  concluido
# 4    5      Joao Santos   52.0  campinas   cardiologia  concluido
# 5    5      Joao Santos   52.0  campinas   cardiologia  concluido
# 14  14   Lucas Ferreira   41.0  campinas   cardiologia   agendado
# 21  21    Mariana Silva   35.0  valinhos     pediatria  concluido
# 29  29   Lucas Ferreira   41.0  campinas   cardiologia   agendado
#
#                         email     telefone
# 3    mariana.silva@email.com   11999990004
# 4       joao.santos@email.com  11999990005
# 5       joao.santos@email.com  11999990005
# 14   lucas.ferreira@email.com  11999990014
# 21    mariana.silva@email.com  11999990004
# 29   lucas.ferreira@email.com  11999990014

# %%
df = df.drop_duplicates(subset="email")

# %%
df.drop_duplicates(subset="email", keep="first")
# Out:
#     id              nome  idade    cidade  especialidade     status  \
# 0    1        Bruno Lima   30.0   vinhedo  clinico geral  concluido
# 1    2         Ana Souza   37.0  campinas    cardiologia   agendado
# 2    3     Carlos Mendes   40.0   jundiai      ortopedia  cancelado
# 3    4    Mariana Silva    35.0  valinhos      pediatria  concluido
# 4    5       Joao Santos   52.0  campinas    cardiologia  concluido
# 6    6    Pedro Oliveira   28.0  campinas    cardiologia  concluido
# 7    7     Juliana Costa   45.0  campinas    cardiologia   agendado
# 8    8    Marcos Pereira   67.0  campinas      ortopedia  cancelado
# 9    9    Fernanda Alves   29.0   vinhedo   dermatologia  concluido
# 10  10      Rafael Souza   37.0   jundiai    cardiologia   agendado
# 11  11     Patricia Lima   38.0  campinas      pediatria  concluido
# 12  12    Gabriel Santos    NaN  valinhos      ortopedia  concluido
# 13  13  Beatriz Oliveira   22.0   vinhedo   dermatologia  cancelado
# ...
